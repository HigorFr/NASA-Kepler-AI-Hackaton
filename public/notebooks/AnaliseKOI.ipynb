# %%
import pandas as pd

df = pd.read_csv(
    "KOIonlyValuesDireto.csv",
    sep=",",        # column separator
    thousands=",",  # comma separates thousands
    decimal="."     # dot separates decimals
)

# %%
df["koi_pdisposition"].value_counts()
