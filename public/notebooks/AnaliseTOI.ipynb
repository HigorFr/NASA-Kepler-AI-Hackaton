# %%
# !pip install lightgbm
# !pip install -U imbalanced-learn
# !pip install skl2onnx
# !pip install onnxmltools

# %% [markdown]
# First we import useful libraries, define the dataset and take a first look at it with df.head() and see some interesting metrics with df.describe()
